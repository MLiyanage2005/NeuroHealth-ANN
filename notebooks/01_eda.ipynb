# %% [markdown]
# # Exploratory Data Analysis
# Perform initial data exploration and visualization.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("../survey.csv")
print(df.head())
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
df.sample(25)
# Out:
#                 Timestamp  Age          Gender         Country state  \
# 1017  2014-08-29 09:58:55   46  Female (trans)   United States    CT
# 755   2014-08-28 11:26:15   29          Female   United States    OR
# 1227  2015-02-21 18:54:12   32          Female         Ireland   NaN
# 9     2014-08-27 11:32:43   23            Male          Canada   NaN
# 995   2014-08-29 09:19:25   35            Male  United Kingdom   NaN
# 859   2014-08-28 17:02:56   32            male  United Kingdom   NaN
# 320   2014-08-27 14:28:41   41            Male   United States    SD
# 958   2014-08-29 03:08:25   26            Male   United States    CA
# 152   2014-08-27 12:41:04   28            male          Poland   NaN
# 1092  2014-08-29 17:35:16   32            Male   United States    TN
# 801   2014-08-28 13:39:40   23            Male   United States    CA
# 640   2014-08-28 03:15:01   36            Male         Germany   NaN
# 1104  2014-08-29 23:51:01   45               M   United States    CA
# 1133  2014-08-31 22:11:48   27               M     New Zealand   NaN
# 1257  2015-11-30 21:25:06   46               f   United States    NC
# 122   2014-08-27 12:33:23   33            Male   United States    MN
# 177   2014-08-27 12:50:57   32          Female   United States    MA
# 439   2014-08-27 15:43:27   29            Male   United States    PA
# 919   2014-08-28 19:28:27   22               F   United States    CA
# 1055  2014-08-29 11:40:29   39            Male   United States    WA
# 426   2014-08-27 15:35:21   24            Male   United States    TX
# 108   2014-08-27 12:28:12   34               m   United States    TN
# 1100  2014-08-29 21:26:44   29            Male   United States    NY
# 452   2014-08-27 15:54:45   30            male   United States    WA
# 78    2014-08-27 11:59:31   32            Male   United States    UT
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 1017            No             No       Yes          Often  More than 1000
# 755             No            Yes       Yes      Sometimes          26-100
# 1227            No            Yes        No          Never  More than 1000
# 9              NaN             No        No          Never          26-100
# 995            Yes             No        No      Sometimes             1-5
# 859             No            Yes       Yes         Rarely            6-25
# 320             No            Yes       Yes         Rarely         100-500
# 958             No             No       Yes         Rarely  More than 1000
# 152             No             No        No         Rarely            6-25
# 1092            No            Yes       Yes          Often         100-500
# 801             No            Yes       Yes      Sometimes            6-25
# 640             No             No        No            NaN          26-100
# 1104            No             No        No          Never            6-25
# 1133            No             No        No         Rarely          26-100
# 1257            No             No        No            NaN         100-500
# 122             No            Yes       Yes      Sometimes            6-25
# 177             No             No       Yes          Often            6-25
# 439             No            Yes       Yes         Rarely             1-5
# 919             No            Yes       Yes          Often  More than 1000
# 1055            No            Yes       Yes      Sometimes        500-1000
# 426             No            Yes       Yes      Sometimes         100-500
# 108             No            Yes        No          Never            6-25
# 1100            No             No        No            NaN            6-25
# 452             No            Yes       Yes          Often  More than 1000
# 78              No            Yes       Yes      Sometimes          26-100
#
#       ...               leave mental_health_consequence  \
# 1017  ...          Don't know                       Yes
# 755   ...          Don't know                     Maybe
# 1227  ...          Don't know                     Maybe
# 9     ...          Don't know                        No
# 995   ...       Somewhat easy                        No
# 859   ...          Don't know                       Yes
# 320   ...       Somewhat easy                        No
# 958   ...          Don't know                        No
# 152   ...          Don't know                        No
# 1092  ...      Very difficult                       Yes
# 801   ...           Very easy                        No
# 640   ...           Very easy                        No
# 1104  ...          Don't know                       Yes
# 1133  ...  Somewhat difficult                       Yes
# 1257  ...          Don't know                       Yes
# 122   ...           Very easy                        No
# 177   ...           Very easy                        No
# 439   ...       Somewhat easy                        No
# 919   ...          Don't know                       Yes
# 1055  ...           Very easy                        No
# 426   ...  Somewhat difficult                       Yes
# 108   ...          Don't know                     Maybe
# 1100  ...          Don't know                     Maybe
# 452   ...      Very difficult                       Yes
# 78    ...  Somewhat difficult                       Yes
#
#      phys_health_consequence     coworkers    supervisor  \
# 1017                      No  Some of them  Some of them
# 755                       No  Some of them           Yes
# 1227                      No  Some of them  Some of them
# 9                         No           Yes           Yes
# 995                       No  Some of them           Yes
# 859                    Maybe  Some of them            No
# 320                       No  Some of them           Yes
# 958                       No  Some of them  Some of them
# 152                       No           Yes           Yes
# 1092                      No           Yes           Yes
# 801                       No  Some of them           Yes
# 640                       No  Some of them           Yes
# 1104                   Maybe  Some of them            No
# 1133                      No            No            No
# 1257                      No            No            No
# 122                       No           Yes           Yes
# 177                       No           Yes           Yes
# 439                       No           Yes           Yes
# 919                      Yes            No            No
# 1055                      No  Some of them           Yes
# 426                       No  Some of them  Some of them
# 108                       No            No            No
# 1100                      No  Some of them           Yes
# 452                       No  Some of them            No
# 78                        No  Some of them            No
#
#      mental_health_interview phys_health_interview mental_vs_physical  \
# 1017                      No                    No                 No
# 755                       No                 Maybe         Don't know
# 1227                      No                    No         Don't know
# 9                      Maybe                 Maybe                Yes
# 995                       No                    No         Don't know
# 859                       No                    No                 No
# 320                    Maybe                 Maybe                Yes
# 958                       No                 Maybe                 No
# 152                    Maybe                   Yes                Yes
# 1092                      No                   Yes                 No
# 801                    Maybe                 Maybe                Yes
# 640                    Maybe                 Maybe                Yes
# 1104                      No                 Maybe         Don't know
# 1133                      No                 Maybe                 No
# 1257                      No                    No                 No
# 122                       No                 Maybe                Yes
# 177                       No                    No                Yes
# 439                    Maybe                 Maybe                Yes
# 919                       No                    No         Don't know
# 1055                      No                    No                Yes
# 426                       No                 Maybe                 No
# 108                       No                    No         Don't know
# 1100                   Maybe                   Yes         Don't know
# 452                       No                    No                 No
# 78                        No                   Yes                 No
#
#      obs_consequence                                           comments
# 1017             Yes                                                NaN
# 755               No                                                NaN
# 1227              No                                                NaN
# 9                 No                                                NaN
# 995               No                                                NaN
# 859               No                                                NaN
# 320               No                                                NaN
# 958               No                                                NaN
# 152               No                                                NaN
# 1092              No                                                NaN
# 801               No                                                NaN
# 640               No                                                NaN
# 1104              No                                                NaN
# 1133             Yes                                                NaN
# 1257              No                                                NaN
# 122               No                                                NaN
# 177              Yes  I am not sure about my company's healthcare be...
# 439               No                                                NaN
# 919               No                                                NaN
# 1055              No                                                NaN
# 426              Yes                                                NaN
# 108               No                                                NaN
# 1100              No                                                NaN
# 452              Yes                                                NaN
# 78                No                                                NaN
#
# [25 rows x 27 columns]

# %%
df.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
#  13  care_options               1259 non-null   object
#  14  wellness_program           1259 non-null   object
#  15  seek_help                  1259 non-null   object
#  16  anonymity                  1259 non-null   object
#  17  leave                      1259 non-null   object
#  18  mental_health_consequence  1259 non-null   object
#  19  phys_health_consequence    1259 non-null   object
#  20  coworkers                  1259 non-null   object
#  21  supervisor                 1259 non-null   object
#  22  mental_health_interview    1259 non-null   object
#  23  phys_health_interview      1259 non-null   object
#  24  mental_vs_physical         1259 non-null   object
#  25  obs_consequence            1259 non-null   object
#  26  comments                   164 non-null    object
# dtypes: int64(1), object(26)
# memory usage: 265.7+ KB

# %%
df.shape
# Out:
# (1259, 27)

# %%
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
df.drop(columns=["comments"], inplace=True)

# %%
df.drop(columns=["state"], inplace=True)

# %%
df["self_employed"].fillna(
    df["self_employed"].mode()[0],
    inplace=True
)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_68880\1524786698.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["self_employed"].fillna(

# %%
df.isnull().sum()
# Out:
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# self_employed                  0
# family_history                 0
# treatment                      0
# work_interfere               264
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %%
df["work_interfere"].fillna(
    "Unknown",
    inplace=True
)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_68880\4287315823.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["work_interfere"].fillna(

# %%
df.isnull().sum()
# Out:
# Timestamp                    0
# Age                          0
# Gender                       0
# Country                      0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
df.drop(columns=["Timestamp"], inplace=True)

# %%
df.sample(25)
# Out:
#       Age  Gender         Country self_employed family_history treatment  \
# 399    29    Male          Canada            No             No       Yes
# 700    30       M   United States            No             No        No
# 1166   29    Male   United States            No            Yes       Yes
# 660    20       F     Switzerland            No             No        No
# 639    49    male           Japan           Yes            Yes       Yes
# 495    23  Female   United States            No            Yes       Yes
# 217    31       M          Canada           Yes             No        No
# 1077   27  Female   United States            No            Yes       Yes
# 240    22    Male          Sweden            No             No        No
# 998    32    Male  United Kingdom            No             No        No
# 568    31    male   United States            No            Yes        No
# 181    26       f           India           Yes             No        No
# 1039   35    Male   United States            No             No        No
# 609    27    Male       Australia            No             No        No
# 245    40       M   United States            No             No       Yes
# 108    34       m   United States            No            Yes        No
# 483    29    male   United States            No             No       Yes
# 131    32    male   United States            No             No        No
# 319    29    male          Latvia            No             No        No
# 940    28    Male   United States            No            Yes       Yes
# 939    44    male   United States            No            Yes       Yes
# 907    25  female   United States            No            Yes       Yes
# 1114   40       m   United States            No             No        No
# 661    27    Male  United Kingdom            No             No        No
# 569    38    Make   United States            No            Yes       Yes
#
#      work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 399       Sometimes         100-500          No          Yes  ...         Yes
# 700         Unknown         100-500          No           No  ...  Don't know
# 1166      Sometimes          26-100          No           No  ...  Don't know
# 660          Rarely  More than 1000          No          Yes  ...         Yes
# 639       Sometimes             1-5         Yes          Yes  ...  Don't know
# 495           Often  More than 1000          No          Yes  ...  Don't know
# 217         Unknown            6-25          No          Yes  ...         Yes
# 1077          Often  More than 1000          No          Yes  ...         Yes
# 240         Unknown            6-25          No          Yes  ...  Don't know
# 998          Rarely        500-1000          No          Yes  ...  Don't know
# 568       Sometimes  More than 1000          No          Yes  ...  Don't know
# 181       Sometimes            6-25          No           No  ...  Don't know
# 1039        Unknown            6-25         Yes          Yes  ...  Don't know
# 609           Never             1-5         Yes          Yes  ...  Don't know
# 245       Sometimes  More than 1000         Yes          Yes  ...         Yes
# 108           Never            6-25         Yes          Yes  ...  Don't know
# 483          Rarely            6-25          No          Yes  ...  Don't know
# 131          Rarely             1-5         Yes          Yes  ...  Don't know
# 319         Unknown          26-100          No          Yes  ...  Don't know
# 940          Rarely  More than 1000          No          Yes  ...  Don't know
# 939       Sometimes            6-25         Yes          Yes  ...         Yes
# 907       Sometimes  More than 1000          No          Yes  ...  Don't know
# 1114        Unknown  More than 1000          No           No  ...  Don't know
# 661           Never             1-5          No          Yes  ...  Don't know
# 569       Sometimes         100-500          No          Yes  ...  Don't know
#
#                    leave mental_health_consequence phys_health_consequence  \
# 399        Somewhat easy                     Maybe                      No
# 700           Don't know                     Maybe                      No
# 1166          Don't know                     Maybe                      No
# 660        Somewhat easy                        No                      No
# 639   Somewhat difficult                       Yes                     Yes
# 495           Don't know                     Maybe                      No
# 217            Very easy                        No                      No
# 1077      Very difficult                     Maybe                      No
# 240           Don't know                        No                      No
# 998           Don't know                       Yes                      No
# 568        Somewhat easy                     Maybe                      No
# 181        Somewhat easy                     Maybe                   Maybe
# 1039          Don't know                        No                      No
# 609           Don't know                       Yes                      No
# 245           Don't know                       Yes                   Maybe
# 108           Don't know                     Maybe                      No
# 483           Don't know                     Maybe                      No
# 131       Very difficult                     Maybe                      No
# 319        Somewhat easy                     Maybe                   Maybe
# 940           Don't know                     Maybe                      No
# 939   Somewhat difficult                     Maybe                   Maybe
# 907           Don't know                       Yes                     Yes
# 1114       Somewhat easy                     Maybe                      No
# 661           Don't know                        No                      No
# 569           Don't know                     Maybe                   Maybe
#
#          coworkers    supervisor mental_health_interview  \
# 399   Some of them  Some of them                      No
# 700   Some of them           Yes                      No
# 1166  Some of them            No                      No
# 660   Some of them  Some of them                      No
# 639             No            No                      No
# 495   Some of them  Some of them                      No
# 217   Some of them  Some of them                      No
# 1077           Yes  Some of them                      No
# 240   Some of them           Yes                   Maybe
# 998             No            No                      No
# 568             No  Some of them                      No
# 181   Some of them  Some of them                      No
# 1039            No            No                      No
# 609             No            No                      No
# 245             No            No                      No
# 108             No            No                      No
# 483   Some of them            No                      No
# 131            Yes  Some of them                      No
# 319   Some of them  Some of them                      No
# 940   Some of them            No                      No
# 939   Some of them           Yes                      No
# 907             No            No                      No
# 1114  Some of them  Some of them                      No
# 661   Some of them           Yes                   Maybe
# 569   Some of them            No                      No
#
#      phys_health_interview mental_vs_physical obs_consequence
# 399                  Maybe                Yes              No
# 700                     No         Don't know              No
# 1166                 Maybe         Don't know              No
# 660                  Maybe                Yes              No
# 639                     No                 No             Yes
# 495                     No                Yes             Yes
# 217                     No                Yes              No
# 1077                 Maybe                 No             Yes
# 240                  Maybe                 No              No
# 998                     No         Don't know              No
# 568                    Yes                 No              No
# 181                     No         Don't know              No
# 1039                    No         Don't know              No
# 609                  Maybe         Don't know              No
# 245                  Maybe                 No             Yes
# 108                     No         Don't know              No
# 483                  Maybe         Don't know              No
# 131                    Yes         Don't know              No
# 319                     No         Don't know              No
# 940                     No                 No              No
# 939                  Maybe                 No              No
# 907                     No                 No              No
# 1114                 Maybe         Don't know              No
# 661                  Maybe         Don't know              No
# 569                     No         Don't know              No
#
# [25 rows x 24 columns]

# %%
df.to_csv(
    "eda_cleaned.csv",
    index=False
)
