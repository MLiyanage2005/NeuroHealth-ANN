# %% [markdown]
# # Exploratory Data Analysis
# Perform initial data exploration and visualization.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("../survey.csv")
print(df.head())
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
df.sample(25)
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 778   2014-08-28 12:10:42   27  Female   United States    WA            No
# 1098  2014-08-29 20:53:09   29    Male   United States    WI            No
# 128   2014-08-27 12:34:48   31    Male  United Kingdom   NaN            No
# 1216  2015-02-21 09:30:14   27    Male  United Kingdom   NaN            No
# 625   2014-08-28 01:56:43   28  Female   United States    CA            No
# 503   2014-08-27 16:34:18   25    Male         Germany   NaN            No
# 262   2014-08-27 13:52:57   30    Male   United States    FL            No
# 1229  2015-02-22 02:40:32   39    Male          Greece   NaN            No
# 141   2014-08-27 12:38:18   37    Male  United Kingdom   NaN           Yes
# 1209  2015-02-21 08:56:27   29    male       Singapore   NaN            No
# 617   2014-08-28 00:43:40   35    Male   United States    MD            No
# 828   2014-08-28 15:40:32   29  female  United Kingdom   NaN            No
# 189   2014-08-27 12:53:13   35  Female   United States    CA            No
# 332   2014-08-27 14:34:47   31    Male   United States    OH            No
# 767   2014-08-28 11:50:28   27    Male  United Kingdom   NaN            No
# 169   2014-08-27 12:48:39   24    Male  United Kingdom   NaN            No
# 790   2014-08-28 12:53:21   29       M  United Kingdom   NaN            No
# 904   2014-08-28 17:59:54   51       m   United States    CO           Yes
# 28    2014-08-27 11:38:12   34    male   United States    OH            No
# 1074  2014-08-29 14:04:59   31       m   United States    CA            No
# 463   2014-08-27 16:02:16   26  Female   United States    CA            No
# 573   2014-08-27 20:48:54   26  Female   United States    MA            No
# 395   2014-08-27 15:25:03   29    Male   United States    TX            No
# 211   2014-08-27 13:06:12   37    Male  United Kingdom   NaN            No
# 311   2014-08-27 14:24:15   35    male   United States    OR            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 778              No        No            NaN  More than 1000  ...
# 1098             No        No            NaN  More than 1000  ...
# 128             Yes        No      Sometimes            6-25  ...
# 1216             No        No         Rarely  More than 1000  ...
# 625             Yes       Yes         Rarely        500-1000  ...
# 503              No        No          Never  More than 1000  ...
# 262              No       Yes      Sometimes         100-500  ...
# 1229             No        No            NaN            6-25  ...
# 141              No       Yes      Sometimes  More than 1000  ...
# 1209            Yes       Yes      Sometimes          26-100  ...
# 617             Yes       Yes         Rarely         100-500  ...
# 828              No       Yes         Rarely            6-25  ...
# 189             Yes       Yes          Never  More than 1000  ...
# 332              No        No            NaN         100-500  ...
# 767              No        No          Never          26-100  ...
# 169              No        No         Rarely         100-500  ...
# 790              No        No         Rarely         100-500  ...
# 904              No        No          Never             1-5  ...
# 28               No       Yes      Sometimes          26-100  ...
# 1074             No       Yes      Sometimes         100-500  ...
# 463             Yes        No          Never          26-100  ...
# 573             Yes       Yes      Sometimes          26-100  ...
# 395              No        No          Never  More than 1000  ...
# 211             Yes        No      Sometimes          26-100  ...
# 311              No       Yes         Rarely         100-500  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# 778           Don't know                     Maybe                      No
# 1098       Somewhat easy                        No                      No
# 128        Somewhat easy                     Maybe                   Maybe
# 1216          Don't know                        No                      No
# 625   Somewhat difficult                     Maybe                      No
# 503           Don't know                        No                      No
# 262           Don't know                        No                      No
# 1229          Don't know                       Yes                      No
# 141       Very difficult                       Yes                     Yes
# 1209  Somewhat difficult                     Maybe                      No
# 617       Very difficult                       Yes                      No
# 828           Don't know                     Maybe                      No
# 189        Somewhat easy                     Maybe                      No
# 332        Somewhat easy                     Maybe                      No
# 767        Somewhat easy                        No                      No
# 169            Very easy                     Maybe                   Maybe
# 790        Somewhat easy                        No                      No
# 904   Somewhat difficult                        No                      No
# 28    Somewhat difficult                        No                      No
# 1074       Somewhat easy                     Maybe                      No
# 463   Somewhat difficult                     Maybe                   Maybe
# 573   Somewhat difficult                        No                      No
# 395           Don't know                     Maybe                      No
# 211           Don't know                       Yes                   Maybe
# 311           Don't know                        No                      No
#
#          coworkers    supervisor mental_health_interview  \
# 778   Some of them           Yes                      No
# 1098  Some of them           Yes                      No
# 128             No            No                      No
# 1216  Some of them           Yes                      No
# 625             No  Some of them                      No
# 503            Yes           Yes                      No
# 262            Yes           Yes                   Maybe
# 1229            No            No                      No
# 141   Some of them            No                      No
# 1209            No            No                      No
# 617   Some of them            No                      No
# 828   Some of them            No                      No
# 189             No            No                      No
# 332             No            No                      No
# 767   Some of them            No                     Yes
# 169   Some of them  Some of them                      No
# 790   Some of them           Yes                      No
# 904   Some of them  Some of them                   Maybe
# 28    Some of them            No                      No
# 1074  Some of them            No                      No
# 463   Some of them            No                      No
# 573            Yes           Yes                      No
# 395   Some of them  Some of them                      No
# 211   Some of them           Yes                      No
# 311   Some of them           Yes                      No
#
#      phys_health_interview mental_vs_physical obs_consequence  \
# 778                     No         Don't know              No
# 1098                 Maybe                Yes              No
# 128                     No                Yes              No
# 1216                    No         Don't know              No
# 625                     No                 No              No
# 503                    Yes         Don't know              No
# 262                     No                Yes              No
# 1229                    No         Don't know              No
# 141                  Maybe                Yes              No
# 1209                 Maybe                 No              No
# 617                  Maybe                 No              No
# 828                  Maybe         Don't know              No
# 189                     No         Don't know              No
# 332                    Yes                 No              No
# 767                    Yes         Don't know              No
# 169                  Maybe         Don't know              No
# 790                  Maybe         Don't know             Yes
# 904                  Maybe         Don't know              No
# 28                      No                 No              No
# 1074                 Maybe                 No              No
# 463                  Maybe                 No              No
# 573                     No                 No             Yes
# 395                     No         Don't know              No
# 211                  Maybe         Don't know              No
# 311                     No         Don't know              No
#
#                                                comments
# 778                                                 NaN
# 1098  Though it doesn't affect me (male) good job fo...
# 128                                                 NaN
# 1216                                                NaN
# 625                                                 NaN
# 503                                                 NaN
# 262                                                 NaN
# 1229                                                NaN
# 141   I'm not a permanent employee so do not get the...
# 1209  it is my opinion that bad mental health is a r...
# 617   I'm diagnosed with Bipolar Disorder. My benefi...
# 828                                                 NaN
# 189                                                 NaN
# 332                                                 NaN
# 767                                                 NaN
# 169                                                 NaN
# 790                                                 NaN
# 904                                                 NaN
# 28                                                  NaN
# 1074                                                NaN
# 463                                                 NaN
# 573                                                 NaN
# 395                                                 NaN
# 211                                                 NaN
# 311                                                 NaN
#
# [25 rows x 27 columns]

# %%
df.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
#  13  care_options               1259 non-null   object
#  14  wellness_program           1259 non-null   object
#  15  seek_help                  1259 non-null   object
#  16  anonymity                  1259 non-null   object
#  17  leave                      1259 non-null   object
#  18  mental_health_consequence  1259 non-null   object
#  19  phys_health_consequence    1259 non-null   object
#  20  coworkers                  1259 non-null   object
#  21  supervisor                 1259 non-null   object
#  22  mental_health_interview    1259 non-null   object
#  23  phys_health_interview      1259 non-null   object
#  24  mental_vs_physical         1259 non-null   object
#  25  obs_consequence            1259 non-null   object
#  26  comments                   164 non-null    object
# dtypes: int64(1), object(26)
# memory usage: 265.7+ KB

# %%
df.shape
# Out:
# (1259, 27)

# %%
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
df.drop(columns=["comments"], inplace=True)

# %%
df.drop(columns=["state"], inplace=True)

# %%
df["self_employed"].fillna(
    df["self_employed"].mode()[0],
    inplace=True
)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_67996\1524786698.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["self_employed"].fillna(

# %%
df.isnull().sum()
# Out:
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# self_employed                  0
# family_history                 0
# treatment                      0
# work_interfere               264
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %%
df["work_interfere"].fillna(
    "Unknown",
    inplace=True
)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_67996\4287315823.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["work_interfere"].fillna(

# %%
df.isnull().sum()
# Out:
# Timestamp                    0
# Age                          0
# Gender                       0
# Country                      0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
df.drop(columns=["Timestamp"], inplace=True)

# %%
df.sample(25)
# Out:
#       Age  Gender        Country self_employed family_history treatment  \
# 156    27    Male  United States            No            Yes       Yes
# 389    33  Female         Sweden            No            Yes       Yes
# 472    29    Male  United States            No             No        No
# 1111   29       M         France            No             No       Yes
# 727    30    Male    Switzerland            No            Yes       Yes
# 792    37  female  United States            No             No       Yes
# 842    31  Female  United States            No            Yes       Yes
# 279    23    Male  United States            No            Yes        No
# 1024   37    Male  United States            No            Yes        No
# 376    27  female  United States            No             No       Yes
# 368    21    Male  United States            No            Yes       Yes
# 227    34    Male      Australia           Yes             No        No
# 832    29    Male         Sweden            No             No       Yes
# 134    24    Male         Canada            No             No       Yes
# 318    22  Female  United States            No            Yes       Yes
# 529    31  Female         Canada           Yes            Yes       Yes
# 358    34    Male  United States            No             No       Yes
# 1012   24  Female  United States            No            Yes        No
# 241    34    male  United States            No            Yes       Yes
# 314    27    Male  United States            No            Yes        No
# 783    33       M  United States           Yes             No        No
# 846    34       M  United States            No             No       Yes
# 830    29    Male  United States            No            Yes        No
# 66     23  Female      Australia            No            Yes       Yes
# 683    29  female         Canada            No             No       Yes
#
#      work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 156       Sometimes  More than 1000          No          Yes  ...  Don't know
# 389          Rarely  More than 1000          No          Yes  ...         Yes
# 472       Sometimes            6-25          No          Yes  ...  Don't know
# 1111          Often            6-25          No          Yes  ...         Yes
# 727       Sometimes          26-100          No          Yes  ...          No
# 792           Often            6-25         Yes          Yes  ...         Yes
# 842       Sometimes         100-500          No          Yes  ...  Don't know
# 279       Sometimes         100-500          No          Yes  ...  Don't know
# 1024      Sometimes          26-100         Yes          Yes  ...  Don't know
# 376          Rarely  More than 1000          No          Yes  ...         Yes
# 368          Rarely         100-500          No          Yes  ...         Yes
# 227       Sometimes             1-5         Yes          Yes  ...  Don't know
# 832          Rarely            6-25          No          Yes  ...         Yes
# 134           Never          26-100          No          Yes  ...  Don't know
# 318           Often  More than 1000          No          Yes  ...         Yes
# 529       Sometimes         100-500         Yes          Yes  ...  Don't know
# 358       Sometimes         100-500         Yes          Yes  ...  Don't know
# 1012      Sometimes  More than 1000          No           No  ...  Don't know
# 241       Sometimes             1-5          No          Yes  ...  Don't know
# 314         Unknown  More than 1000          No          Yes  ...  Don't know
# 783         Unknown             1-5          No          Yes  ...  Don't know
# 846       Sometimes         100-500          No          Yes  ...         Yes
# 830       Sometimes  More than 1000         Yes           No  ...         Yes
# 66            Often             1-5         Yes          Yes  ...  Don't know
# 683          Rarely  More than 1000         Yes           No  ...         Yes
#
#                    leave mental_health_consequence phys_health_consequence  \
# 156           Don't know                        No                      No
# 389           Don't know                     Maybe                      No
# 472       Very difficult                       Yes                      No
# 1111       Somewhat easy                     Maybe                   Maybe
# 727       Very difficult                       Yes                     Yes
# 792   Somewhat difficult                       Yes                      No
# 842   Somewhat difficult                        No                      No
# 279           Don't know                     Maybe                      No
# 1024       Somewhat easy                     Maybe                      No
# 376           Don't know                       Yes                   Maybe
# 368           Don't know                        No                      No
# 227   Somewhat difficult                       Yes                     Yes
# 832            Very easy                        No                      No
# 134           Don't know                        No                      No
# 318        Somewhat easy                     Maybe                      No
# 529           Don't know                     Maybe                   Maybe
# 358        Somewhat easy                       Yes                     Yes
# 1012  Somewhat difficult                       Yes                   Maybe
# 241   Somewhat difficult                     Maybe                      No
# 314            Very easy                        No                      No
# 783           Don't know                        No                      No
# 846           Don't know                     Maybe                      No
# 830            Very easy                     Maybe                      No
# 66             Very easy                        No                      No
# 683        Somewhat easy                        No                      No
#
#          coworkers    supervisor mental_health_interview  \
# 156             No  Some of them                      No
# 389   Some of them            No                      No
# 472             No            No                      No
# 1111           Yes  Some of them                      No
# 727             No            No                      No
# 792   Some of them  Some of them                      No
# 842            Yes           Yes                   Maybe
# 279   Some of them            No                      No
# 1024  Some of them  Some of them                      No
# 376             No            No                      No
# 368            Yes           Yes                   Maybe
# 227             No            No                      No
# 832   Some of them           Yes                      No
# 134   Some of them           Yes                   Maybe
# 318             No  Some of them                      No
# 529   Some of them           Yes                      No
# 358   Some of them  Some of them                      No
# 1012  Some of them  Some of them                      No
# 241   Some of them  Some of them                      No
# 314            Yes           Yes                   Maybe
# 783            Yes           Yes                      No
# 846   Some of them            No                      No
# 830   Some of them            No                      No
# 66    Some of them           Yes                      No
# 683             No           Yes                      No
#
#      phys_health_interview mental_vs_physical obs_consequence
# 156                  Maybe         Don't know              No
# 389                    Yes         Don't know              No
# 472                  Maybe                 No              No
# 1111                   Yes                 No              No
# 727                     No                 No              No
# 792                    Yes                 No             Yes
# 842                  Maybe         Don't know              No
# 279                  Maybe                 No              No
# 1024                 Maybe                 No              No
# 376                     No                 No              No
# 368                  Maybe         Don't know              No
# 227                  Maybe                Yes              No
# 832                     No                Yes              No
# 134                    Yes         Don't know              No
# 318                     No                Yes             Yes
# 529                     No                Yes              No
# 358                  Maybe         Don't know              No
# 1012                    No                 No             Yes
# 241                  Maybe                 No             Yes
# 314                  Maybe                Yes              No
# 783                  Maybe         Don't know              No
# 846                     No         Don't know              No
# 830                     No                Yes              No
# 66                   Maybe                Yes              No
# 683                  Maybe         Don't know              No
#
# [25 rows x 24 columns]

# %%
df.to_csv(
    "eda_cleaned.csv",
    index=False
)
